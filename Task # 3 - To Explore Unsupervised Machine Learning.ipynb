# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
path="D:\yuvraj\dataset\iris.csv"
iris=pd.read_csv(path)

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.Species.unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
corrMatrix = iris.iloc[:,[1, 2, 3, 4]].corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
X= iris.iloc[:, [1, 2, 3, 4]].values

# %%
wcss=[]

for k in range(1,11):
    kmeans=KMeans(n_clusters=k,init='k-means++',max_iter=300,random_state=0).fit(X)
    
    wcss.append(kmeans.inertia_)
    
len(wcss)
print(wcss)
# Out:
# [680.8243999999996, 152.36870647733915, 78.94084142614601, 57.34540931571815, 46.535582051282034, 38.93873974358975, 34.190687924796634, 29.90537429982511, 27.927882157034986, 25.955497086247092]

# %%
plt.plot(wcss)
plt.title('Clusters vs WCSS')
plt.xlabel('Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Apply Kmeans to the dataset
clusters=KMeans(n_clusters=3,init='k-means++',max_iter=300,random_state=0).fit_predict(X)

# %%
#Plot Graphs to represent columns by clusters
plt.scatter(X[clusters == 0, 0], X[clusters == 0, 1], 
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(X[clusters == 1, 0], X[clusters == 1, 1], 
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(X[clusters == 2, 0], X[clusters == 2, 1],
            s = 70, c = 'green', label = 'Iris-virginica')

plt.legend()

# %%
plt.scatter(X[clusters == 0, 0], X[clusters == 0, 2], 
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(X[clusters == 1, 0], X[clusters == 1, 2], 
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(X[clusters == 2, 0], X[clusters == 2, 2],
            s = 70, c = 'green', label = 'Iris-virginica')

plt.legend()

# %%
plt.scatter(X[clusters == 0, 2], X[clusters == 0, 3], 
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(X[clusters == 1, 2], X[clusters == 1, 3], 
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(X[clusters == 2, 2], X[clusters == 2, 3],
            s = 70, c = 'green', label = 'Iris-virginica')

plt.legend()

# %%
plt.scatter(X[clusters == 0, 0], X[clusters == 0, 3], 
            s = 70, c = 'red', label = 'Iris-setosa')
plt.scatter(X[clusters == 1, 0], X[clusters == 1, 3], 
            s = 70, c = 'blue', label = 'Iris-versicolour')
plt.scatter(X[clusters == 2, 0], X[clusters == 2, 3],
            s = 70, c = 'green', label = 'Iris-virginica')

plt.legend()
